# %% [markdown]
# # Propaganda, start the `spark` session
#
# > For SQL users, Spark SQL provides state-of-the-art SQL performance and maintains compatibility with Shark/Hive. In particular, like Shark, Spark SQL supports all existing Hive data formats, user-defined functions (UDF), and the Hive metastore.
#
# > For Spark users, Spark SQL becomes the narrow-waist for manipulating (semi-) structured data as well as ingesting data from sources that provide schema, such as JSON, Parquet, Hive, or EDWs. It truly unifies SQL and sophisticated analysis, allowing users to mix and match SQL and more imperative programming APIs for advanced analytics.
#
# > For open source hackers, Spark SQL proposes a novel, elegant way of building query planners. It is incredibly easy to add new optimizations under this framework.
#
# > Internally, a structured query is a Catalyst tree of (logical and physical) relational operators and expressions.

# %%
# import the usual suspects
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from pathlib import Path
import sys
import timeit

# %matplotlib inline
import seaborn as sns

sns.set_context("notebook", font_scale=1.2)

# %% [markdown]
# During the session, we will use classes and functions exported by `pyspark`

# %%
# spark
from pyspark import SparkConf, SparkContext
from pyspark.sql import SparkSession
from pyspark.sql import Window
from pyspark.sql.functions import col
import pyspark.sql.functions as fn
from pyspark.sql.catalog import Catalog
from pyspark.sql.types import StructType, StructField
from pyspark.sql.types import IntegerType, StringType

# %% [markdown]
# Start the `SparkSession`

# %%
conf = SparkConf().setAppName("Spark SQL Illustrations")
sc = SparkContext(conf=conf)

spark = (SparkSession
    .builder
    .appName("Spark SQL")
    .getOrCreate()
)

# %% [markdown]
# US Baby Names 1880-2017
# =======================
#
#
# Description
# : US baby names provided by the SSA.
#
# This dataset contains all names used
# for at least 5 children of either sex during a year.
#
#
# The file is made of `1924665` lines and  4 columns.
#
# ```
# |-- name: string (nullable = true)
#     |-- n: integer (nullable = true)
#     |-- sex: string (nullable = true)
#     |-- year: integer (nullable = true)
# ```
#
# Each row indicates for a given name, sex, and year the number of babies
# of the given sex who were given that name during the given year. Names
# with less than 5 occurrences during the year were note recorded.
#
# |    name|  n|sex|year|
# |:--------|:---:|:---:|:----:|
# |  Emilia|112|  F|1985|
# |   Kelsi|112|  F|1985|
# |  Margot|112|  F|1985|
# |  Mariam|112|  F|1985|
# |Scarlett|112|  F|1985|
#
# First, we download the data if it's not there yet

# %%
import requests, zipfile, io
from pathlib import Path

path = Path('babynames_short.csv')
if not path.exists():
    url = "https://stephanegaiffas.github.io/big_data_course/data/babynames_short.csv.zip"
    r = requests.get(url)
    z = zipfile.ZipFile(io.BytesIO(r.content))
    z.extractall(path='./')

# %% [markdown]
# Load `babynames` from a `csv` file

# %%
df_sp = spark.read\
             .format('csv')\
             .option("header", "true")\
             .option("mode", "FAILFAST")\
             .option("inferSchema", "true")\
             .option("sep", ",")\
             .load("babynames_short.csv")

df_sp.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- n: integer (nullable = true)
#  |-- sex: string (nullable = true)
#  |-- year: double (nullable = true)

# %% [markdown]
# Ensure that the dataframe has the following schema:
#
#     root
#         |-- name: string (nullable = true)
#         |-- n: integer (nullable = true)
#         |-- sex: string (nullable = true)
#         |-- year: integer (nullable = true)

# %%
df_sp = df_sp.selectExpr(
    "name",
    "n",
    "sex",
    "cast(year as int) year")
df_sp.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- n: integer (nullable = true)
#  |-- sex: string (nullable = true)
#  |-- year: integer (nullable = true)

# %% [markdown]
# SQL versus spark-Dataframe API
# =================================
#
# >  Dataset API vs SQL
#
# > Spark SQL supports two "modes" to write structured queries: Dataset API and SQL. SQL Mode is used to express structured queries using SQL statements using SparkSession.sql operator, expr standard function and spark-sql command-line tool.
#
# > Some structured queries can be expressed much easier using Dataset API, but there are some that are only possible in SQL. In other words, you may find mixing Dataset API and SQL modes challenging yet rewarding.
#
# > What is important, and one of the reasons why Spark SQL has been so successful, is that there is no performance difference between the modes. Whatever mode you use to write your structured queries, they all end up as a tree of Catalyst relational data structures. And, yes, you could consider writing structured queries using Catalyst directly, but that could quickly become unwieldy for maintenance (i.e. finding Spark SQL developers who could be comfortable with it as well as being fairly low-level and therefore possibly too dependent on a specific Spark SQL version).
#
# Warmup:  compute the 10 most popular names given to babies in year 2000.
# ======================================================================
#
# ## Using `spark.sql()`
#
# In order to use mode `sql`, create a temporary view from the `DataFrame`.
#
# 1. What are temporary views made of?
#
# Temporary views are made of tables.
#
# 2. Are there other kind of views in spark's world?
#
# There are two types of temporary views : local and global.

# %%
Catalog(spark).listTables()
# Out:
# []

# %%
df_sp.createOrReplaceTempView("df_sp")

Catalog(spark).listTables()
# Out:
# [Table(name='df_sp', database=None, description=None, tableType='TEMPORARY', isTemporary=True)]

# %% [markdown]
# ## A query is a plain SQL query embodied in a string.

# %%
query = """ 
SELECT * 
FROM df_sp 
LIMIT 10
"""
spark.sql(query).show()
# Out:
# +--------+---+---+----+
# |    name|  n|sex|year|
# +--------+---+---+----+
# |  Emilia|112|  F|1985|
# |   Kelsi|112|  F|1985|
# |  Margot|112|  F|1985|
# |  Mariam|112|  F|1985|
# |Scarlett|112|  F|1985|
# |    Aida|111|  F|1985|
# |  Ashlei|111|  F|1985|
# |   Greta|111|  F|1985|
# |  Jaimee|111|  F|1985|
# |   Lorna|111|  F|1985|
# +--------+---+---+----+

# %% [markdown]
# > This phrasing is not consistent with the DRY principle. Fix this using formatted strings.
#
# ## Using the dataframe/dataset API
#
# This can also be done using Spark SQL API.
#
# ### Pedestrian approach
#
# 1. First select `10` most popular names for girls in year `2000`, define `spark` dataframe
# `top10_2000_f`.
# 1. Does the definition of `top10_2000_f` involve _transformations_, _actions_ or both?
# 1. What is the type of the result returned by `top10_2000_f.take(2)`? the type of elements of the result?

# %%
top10_2000_f = df_sp.where("sex == 'F'")\
                    .where("year == 2000")\
                    .orderBy(df_sp.n.desc())\
                    .limit(10)
#Only actions are involved in the definition of top10_2000_f
top10_2000_f.show()
print(top10_2000_f.take(2))
#It gives us the two first rows of the table
print(type(top10_2000_f.take(2)))
# Out:
# +---------+-----+---+----+
# |     name|    n|sex|year|
# +---------+-----+---+----+
# |    Emily|25953|  F|2000|
# |   Hannah|23080|  F|2000|
# |  Madison|19967|  F|2000|
# |   Ashley|17997|  F|2000|
# |    Sarah|17697|  F|2000|
# |   Alexis|17629|  F|2000|
# | Samantha|17266|  F|2000|
# |  Jessica|15709|  F|2000|
# |Elizabeth|15094|  F|2000|
# |   Taylor|15078|  F|2000|
# +---------+-----+---+----+
#
# [Row(name='Emily', n=25953, sex='F', year=2000), Row(name='Hannah', n=23080, sex='F', year=2000)]
# <class 'list'>

# %% [markdown]
# 1. Do the same thing for boys.

# %%
top10_2000_m = df_sp.where("sex == 'M'")\
                    .where("year == 2000")\
                    .orderBy(df_sp.n.desc())\
                    .limit(10)
top10_2000_m.show()
# Out:
# +-----------+-----+---+----+
# |       name|    n|sex|year|
# +-----------+-----+---+----+
# |      Jacob|34471|  M|2000|
# |    Michael|32035|  M|2000|
# |    Matthew|28572|  M|2000|
# |     Joshua|27538|  M|2000|
# |Christopher|24931|  M|2000|
# |   Nicholas|24652|  M|2000|
# |     Andrew|23639|  M|2000|
# |     Joseph|22825|  M|2000|
# |     Daniel|22312|  M|2000|
# |      Tyler|21503|  M|2000|
# +-----------+-----+---+----+

# %% [markdown]
# 1. Compute the _union_ of the two spark dataframes. Store the result in
# dataframe `top10_2000`

# %%
top10_2000 = top10_2000_m.unionAll(top10_2000_f)
top10_2000.show()
# Out:
# +-----------+-----+---+----+
# |       name|    n|sex|year|
# +-----------+-----+---+----+
# |      Jacob|34471|  M|2000|
# |    Michael|32035|  M|2000|
# |    Matthew|28572|  M|2000|
# |     Joshua|27538|  M|2000|
# |Christopher|24931|  M|2000|
# |   Nicholas|24652|  M|2000|
# |     Andrew|23639|  M|2000|
# |     Joseph|22825|  M|2000|
# |     Daniel|22312|  M|2000|
# |      Tyler|21503|  M|2000|
# |      Emily|25953|  F|2000|
# |     Hannah|23080|  F|2000|
# |    Madison|19967|  F|2000|
# |     Ashley|17997|  F|2000|
# |      Sarah|17697|  F|2000|
# |     Alexis|17629|  F|2000|
# |   Samantha|17266|  F|2000|
# |    Jessica|15709|  F|2000|
# |  Elizabeth|15094|  F|2000|
# |     Taylor|15078|  F|2000|
# +-----------+-----+---+----+

# %% [markdown]
# ### Do it again, complying  with DRY principle

# %%
#DRY : don't repeat yourself
df_spOrdered2000 = df_sp.orderBy(df_sp.n.desc()).where("year == 2000")

top10_2000 = df_spOrdered2000.where("sex == 'M'")\
                                    .limit(10)\
                                    .union(df_spOrdered2000.where("sex == 'F'").limit(10))

top10_2000.show()
# Out:
# +-----------+-----+---+----+
# |       name|    n|sex|year|
# +-----------+-----+---+----+
# |      Jacob|34471|  M|2000|
# |    Michael|32035|  M|2000|
# |    Matthew|28572|  M|2000|
# |     Joshua|27538|  M|2000|
# |Christopher|24931|  M|2000|
# |   Nicholas|24652|  M|2000|
# |     Andrew|23639|  M|2000|
# |     Joseph|22825|  M|2000|
# |     Daniel|22312|  M|2000|
# |      Tyler|21503|  M|2000|
# |      Emily|25953|  F|2000|
# |     Hannah|23080|  F|2000|
# |    Madison|19967|  F|2000|
# |     Ashley|17997|  F|2000|
# |      Sarah|17697|  F|2000|
# |     Alexis|17629|  F|2000|
# |   Samantha|17266|  F|2000|
# |    Jessica|15709|  F|2000|
# |  Elizabeth|15094|  F|2000|
# |     Taylor|15078|  F|2000|
# +-----------+-----+---+----+

# %% [markdown]
# Name portfolio through ages
# ===========================
#
# 1. Compute for each year and sex the number of distinct names given that year.

# %%
nb_names_year_sex = df_sp.groupBy([df_sp.year,df_sp.sex])\
                        .count()
nb_names_year_sex.orderBy("year","sex").show()
# Out:
# +----+---+-----+
# |year|sex|count|
# +----+---+-----+
# |1880|  F|  942|
# |1880|  M| 1058|
# |1881|  F|  938|
# |1881|  M|  997|
# |1882|  F| 1028|
# |1882|  M| 1099|
# |1883|  F| 1054|
# |1883|  M| 1030|
# |1884|  F| 1172|
# |1884|  M| 1125|
# |1885|  F| 1197|
# |1885|  M| 1097|
# |1886|  F| 1282|
# |1886|  M| 1110|
# |1887|  F| 1306|
# |1887|  M| 1067|
# |1888|  F| 1474|
# |1888|  M| 1177|
# |1889|  F| 1479|
# |1889|  M| 1111|
# +----+---+-----+
# only showing top 20 rows

# %% [markdown]
# 1. Plot the evolution of the number of distinct names as a function of `year`.
# Use some aesthetics to distinguish sexes.

# %%
nb_names_year_sex_pd = nb_names_year_sex.toPandas()

g = sns.lineplot(x = "year",
                y = "count",
                hue = "sex",
                data = nb_names_year_sex_pd)

g.set_title("Number of distinct names over the years")
plt.ylabel("Number of distinct names")
plt.show(g)

# %% [markdown]
# Assessing popularity through time
# =================================
#
# 1. For each year and sex, compute the total number of births
# 1. Plot the evolution of the sex ratio over time
# 1. For each year, sex, and name compute the percentage of newborns
# given that name for that given year.
#
#
# > Use `Window` functions.

# %%
#without Window functions
#nb_birth_year = df_sp.groupBy(df_sp.year,df_sp.sex)\
#                        .agg(fn.sum("n").alias("total")) 
#nb_birth_year.orderBy("year","sex").show()

#with Window functions but it's slower 
window = Window.partitionBy('year','sex')

nb_birth_year = df_sp.withColumn('total',fn.sum('n').over(window))

nb_birth_year = nb_birth_year.select('year','sex','total').distinct()

nb_birth_year.orderBy("year","sex").show()
# Out:
# +----+---+------+
# |year|sex| total|
# +----+---+------+
# |1880|  F| 90993|
# |1880|  M|110491|
# |1881|  F| 91953|
# |1881|  M|100743|
# |1882|  F|107847|
# |1882|  M|113686|
# |1883|  F|112319|
# |1883|  M|104627|
# |1884|  F|129020|
# |1884|  M|114442|
# |1885|  F|133055|
# |1885|  M|107799|
# |1886|  F|144533|
# |1886|  M|110784|
# |1887|  F|145981|
# |1887|  M|101413|
# |1888|  F|178622|
# |1888|  M|120851|
# |1889|  F|178366|
# |1889|  M|110580|
# +----+---+------+
# only showing top 20 rows

# %%
df_sex_ratio = nb_birth_year.groupBy("year")\
                .pivot("sex")\
                .sum("total")
df_sex_ratio = df_sex_ratio.withColumn("sex_ratio", df_sex_ratio.M/df_sex_ratio.F)

# %%
g = sns.lineplot(x = "year",
                y = "sex_ratio",
                data = df_sex_ratio.toPandas())

g.set_title("Ratio of birth (male/female) over the years")
#there should be a ratio of around 1 on a population we trace a line to compare
plt.plot(np.linspace(1880,2020,141),np.array([1]*141),'r')
plt.ylabel("Sex ratio")
plt.show(g)

# %%
window = Window.partitionBy("sex","year")

percent_df_sp = df_sp.withColumn("total/year",fn.sum("n").over(window))

percent_df_sp = percent_df_sp.withColumn("name_proportion", percent_df_sp.n/percent_df_sp["total/year"]*100)

percent_df_sp.show()
# Out:
# +---------+-----+---+----+----------+------------------+
# |     name|    n|sex|year|total/year|   name_proportion|
# +---------+-----+---+----+----------+------------------+
# | Jennifer|50561|  F|1984|   1683380|3.0035404959070444|
# |  Jessica|45855|  F|1984|   1683380|2.7239838895555373|
# |   Ashley|38770|  F|1984|   1683380| 2.303104468390975|
# |   Amanda|33907|  F|1984|   1683380| 2.014221387921919|
# |    Sarah|25882|  F|1984|   1683380|1.5375019306395465|
# |Stephanie|23022|  F|1984|   1683380|1.3676056505364207|
# |   Nicole|22264|  F|1984|   1683380|1.3225771958797181|
# |  Melissa|21889|  F|1984|   1683380|1.3003005857263363|
# |  Heather|21491|  F|1984|   1683380|1.2766576768168802|
# |Elizabeth|20364|  F|1984|   1683380|  1.20970903776925|
# |    Megan|16979|  F|1984|   1683380|1.0086255034513893|
# |  Crystal|16561|  F|1984|   1683380|0.9837945086670864|
# |      Amy|15990|  F|1984|   1683380|0.9498746569402037|
# |  Tiffany|15855|  F|1984|   1683380|0.9418550772849862|
# |   Rachel|15837|  F|1984|   1683380|0.9407857999976238|
# | Danielle|15670|  F|1984|   1683380| 0.930865282942651|
# | Michelle|15498|  F|1984|   1683380|0.9206477444189666|
# |    Amber|15367|  F|1984|   1683380|0.9128657819387185|
# |    Laura|14813|  F|1984|   1683380|0.8799558032054557|
# |Christina|14702|  F|1984|   1683380|0.8733619266000546|
# +---------+-----+---+----+----------+------------------+
# only showing top 20 rows

# %% [markdown]
# 1. Compute for each year, sex and name  the `row_number`, `rank`, and `dense_rank`
# of the name within that year and sex category, when names are sorted by increasing popularity.

# %%
window = Window.partitionBy('year','sex')\
        .orderBy(df_sp.n.asc())

rank = fn.rank().over(window)
dense_rank = fn.dense_rank().over(window)
row_number = fn.row_number().over(window)

df_sp\
    .withColumn('rank', rank)\
    .withColumn('dense_rank', dense_rank)\
    .withColumn('row_number', row_number)\
    .orderBy(df_sp.n.desc()).show()
# Out:
# +-------+-----+---+----+----+----------+----------+
# |   name|    n|sex|year|rank|dense_rank|row_number|
# +-------+-----+---+----+----+----------+----------+
# |  Linda|99686|  F|1947|6103|       683|      6103|
# |  Linda|96209|  F|1948|6040|       683|      6040|
# |  James|94756|  M|1947|4268|       599|      4268|
# |Michael|92695|  M|1957|4552|       650|      4552|
# | Robert|91642|  M|1947|4267|       598|      4267|
# |  Linda|91016|  F|1949|6065|       673|      6065|
# |Michael|90620|  M|1956|4450|       645|      4450|
# |Michael|90520|  M|1958|4499|       652|      4499|
# |  James|88588|  M|1948|4199|       605|      4199|
# |Michael|88514|  M|1954|4352|       626|      4352|
# |Michael|88335|  M|1955|4388|       629|      4388|
# |   John|88318|  M|1947|4266|       597|      4266|
# |  James|87431|  M|1946|4019|       588|      4019|
# |  James|87272|  M|1951|4251|       603|      4251|
# |  James|87107|  M|1952|4257|       607|      4257|
# |Michael|86922|  M|1961|4652|       658|      4652|
# |  James|86855|  M|1949|4203|       601|      4203|
# | Robert|86622|  M|1952|4256|       606|      4256|
# | Robert|86361|  M|1951|4250|       602|      4250|
# |  James|86288|  M|1954|4350|       625|      4350|
# +-------+-----+---+----+----+----------+----------+
# only showing top 20 rows

# %% [markdown]
# Evolution of top popular names through the century
# ==================================================
#
#
# 1. For each sex, select the ten most popular names in year 2000, and plot the proportion
# of newborns given that name over time. Take into account that some names might have
# zero occurrence during certain years.

# %%
pop_name = percent_df_sp.join(top10_2000.select("name","sex"),["name","sex"],'right')

plt.figure(figsize = (14,10))

g = sns.lineplot(x = "year",
                y = "name_proportion",
                 hue = "name",
                data = pop_name.where("sex == 'M'").toPandas())

g.set_title("Popularity of top 10 male names in 2000 through the century")
plt.ylabel("Newborns given that name (percent %)")
plt.show(g)

# %%
plt.figure(figsize = (14,10))

g = sns.lineplot(x = "year",
                y = "name_proportion",
                 hue = "name",
                data = pop_name.where("sex == 'F'").toPandas())

g.set_title("Popularity of top 10 female name in 2000 through the century")
plt.ylabel("Newborns given that name (percent %)")
plt.show(g)

# %% [markdown]
# 1. Use `explain()` to determine the joining strategy used by spark.

# %%
pop_name.explain()
# Out:
# == Physical Plan ==
# *(8) Project [name#2906, sex#2908, n#11, year#18, total/year#2803L, name_proportion#2809]
# +- SortMergeJoin [name#10, sex#12], [name#2906, sex#2908], RightOuter
#    :- *(4) Sort [name#10 ASC NULLS FIRST, sex#12 ASC NULLS FIRST], false, 0
#    :  +- Exchange hashpartitioning(name#10, sex#12, 200)
#    :     +- *(3) Project [name#10, n#11, sex#12, year#18, total/year#2803L, ((cast(n#11 as double) / cast(total/year#2803L as double)) * 100.0) AS name_proportion#2809]
#    :        +- *(3) Filter isnotnull(name#10)
#    :           +- Window [sum(cast(n#11 as bigint)) windowspecdefinition(sex#12, year#18, specifiedwindowframe(RowFrame, unboundedpreceding$(), unboundedfollowing$())) AS total/year#2803L], [sex#12, year#18]
#    :              +- *(2) Sort [sex#12 ASC NULLS FIRST, year#18 ASC NULLS FIRST], false, 0
#    :                 +- Exchange hashpartitioning(sex#12, year#18, 200)
#    :                    +- *(1) Project [name#10, n#11, sex#12, cast(year#13 as int) AS year#18]
#    :                       +- *(1) Filter (((sex#12 = M) || (sex#12 = F)) && isnotnull(sex#12))
#    :                          +- *(1) FileScan csv [name#10,n#11,sex#12,year#13] Batched: false, Format: CSV, Location: InMemoryFileIndex[file:/opt/polynote/notebooks/TheBigData/babynames_short.csv], PartitionFilters: [], PushedFilters: [Or(EqualTo(sex,M),EqualTo(sex,F)), IsNotNull(sex)], ReadSchema: struct<name:string,n:int,sex:string,year:double>
#    +- *(7) Sort [name#2906 ASC NULLS FIRST, sex#2908 ASC NULLS FIRST], false, 0
#       +- Exchange hashpartitioning(name#2906, sex#2908, 200)
#          +- Union
#             :- TakeOrderedAndProject(limit=10, orderBy=[n#2907 DESC NULLS LAST], output=[name#2906,sex#2908])
#             :  +- *(5) Project [name#2906, n#2907, sex#2908]
#             :     +- *(5) Filter (((isnotnull(year#2909) && isnotnull(sex#2908)) && (cast(year#2909 as int) = 2000)) && (sex#2908 = M))
#             :        +- *(5) FileScan csv [name#2906,n#2907,sex#2908,year#2909] Batched: false, Format: CSV, Location: InMemoryFileIndex[file:/opt/polynote/notebooks/TheBigData/babynames_short.csv], PartitionFilters: [], PushedFilters: [IsNotNull(year), IsNotNull(sex), EqualTo(sex,M)], ReadSchema: struct<name:string,n:int,sex:string,year:double>
#             +- TakeOrderedAndProject(limit=10, orderBy=[n#2907 DESC NULLS LAST], output=[name#2906,sex#2908])
#                +- *(6) Project [name#2906, n#2907, sex#2908]
#                   +- *(6) Filter (((isnotnull(year#2909) && isnotnull(sex#2908)) && (cast(year#2909 as int) = 2000)) && (sex#2908 = F))
#                      +- *(6) FileScan csv [name#2906,n#2907,sex#2908,year#2909] Batched: false, Format: CSV, Location: InMemoryFileIndex[file:/opt/polynote/notebooks/TheBigData/babynames_short.csv], PartitionFilters: [], PushedFilters: [IsNotNull(year), IsNotNull(sex), EqualTo(sex,F)], ReadSchema: struct<name:string,n:int,sex:string,year:double>

# %% [markdown]
# Plot the total popularity of the top ten achievers from year 2000 with respect to time
# ==================================================================================

# %%
window = Window.partitionBy('year','sex')

pop_name_t = pop_name.withColumn('tot_nr',fn.sum('name_proportion').over(window))

# %%
g = sns.FacetGrid(pop_name_t.toPandas(), col = "sex", hue = "sex", height = 6)

g = g.map(sns.lineplot,"year","tot_nr")

g.fig.subplots_adjust(top = 0.8)
g.fig.suptitle("Total popularity of top 10 names in 2000 through the century")
g.set_ylabels("Newborns given top10 names (percent %)")

# %% [markdown]
# Plot lorenz curves
# =====================
#
# Every year, the name counts define a discrete probability distribution.
# This distribution, just as income or wealth distribution,
# is (usually) far from being uniform. We want to assess how uneven it is.
# We use the tools developed in econometrics.
#
# Without loss of generality, that we handle a distribution over $1, \ldots, n$
# where $n$ is the number of distinct names given during a year.
# We assume that frequencies $p_1, p_2, \ldots, p_n$ are given in ascending order.
#
# The Lorenz function maps $[0, 1] \to [0, 1]$.
# $$L(x) = \sum_{i=1}^{\lfloor nx \rfloor} p_i$$.
#
# 1. Design a query that adds a column "lorenz" to the dataframe , and for each
# row computes the value of the Lorenz function defined by `year`  and `sex`.

# %%
window = Window.partitionBy("year","sex").orderBy("name_proportion").rowsBetween(Window.unboundedPreceding,0)
window1 = Window.partitionBy("year","sex").orderBy("name_proportion")
window2 = Window.partitionBy("year","sex")
lor_df_sp = percent_df_sp.withColumn("lorenz",fn.sum("name_proportion").over(window)/100)\
                         .withColumn("row", fn.row_number().over(window1))\
                         .withColumn("normrow",col("row")/fn.max("row").over(window2))

lor_df_sp = lor_df_sp.drop("total/year","name_proportion")
lor_df_sp.where("year == 2000 and sex == 'M'").orderBy("lorenz").show()
# Out:
# +-----------+---+---+----+--------------------+---+--------------------+
# |       name|  n|sex|year|              lorenz|row|             normrow|
# +-----------+---+---+----+--------------------+---+--------------------+
# |    Aadarsh|  5|  M|2000|2.547161977596182E-6|  1|8.253549026081215E-5|
# | Aaronjacob|  5|  M|2000|5.094323955192364E-6|  2|1.650709805216243E-4|
# |Aaronjoshua|  5|  M|2000|7.641485932788545E-6|  3|2.476064707824364...|
# |      Aarya|  5|  M|2000|1.018864791038472...|  4|3.301419610432486E-4|
# |       Abad|  5|  M|2000|1.273580988798091E-5|  5|4.126774513040607...|
# |     Abbott|  5|  M|2000|1.528297186557709...|  6|4.952129415648729E-4|
# |Abdalrahman|  5|  M|2000|1.783013384317327...|  7| 5.77748431825685E-4|
# |   Abdiaziz|  5|  M|2000|2.037729582076945...|  8|6.602839220864972E-4|
# |     Abdula|  5|  M|2000|2.292445779836563...|  9|7.428194123473093E-4|
# |    Abdulai|  5|  M|2000|2.547161977596181...| 10|8.253549026081215E-4|
# | Abdulhalim|  5|  M|2000|2.801878175355799...| 11|9.078903928689336E-4|
# |Abdulkareem|  5|  M|2000|3.056594373115417...| 12|9.904258831297458E-4|
# | Abdulmajid|  5|  M|2000|3.311310570875035E-5| 13|0.001072961373390558|
# |    Abhijay|  5|  M|2000|3.566026768634654E-5| 14| 0.00115549686365137|
# |   Abhilash|  5|  M|2000|3.820742966394272E-5| 15|0.001238032353912...|
# |    Abishai|  5|  M|2000| 4.07545916415389E-5| 16|0.001320567844172...|
# |  Aboubacar|  5|  M|2000|4.330175361913508...| 17|0.001403103334433...|
# |     Abraam|  5|  M|2000|4.584891559673126...| 18|0.001485638824694...|
# |     Abriel|  5|  M|2000|4.839607757432744...| 19|0.001568174314955...|
# |   Abubaker|  5|  M|2000|5.094323955192362E-5| 20|0.001650709805216243|
# +-----------+---+---+----+--------------------+---+--------------------+
# only showing top 20 rows

# %% [markdown]
# 1. Design a function that takes as input a `year` and plots the Lorenz curve
# for that year for both sexes.

# %%
def lorenzCurve(a):
    plt.figure(figsize = (14,10))
    g = sns.lineplot(x = "normrow",
                     y = "lorenz",
                     hue = "sex",
                     data = lor_df_sp.where("year == {0}".format(a)).toPandas())
    plt.plot(np.linspace(0,1),np.linspace(0,1), linestyle = ':',color = 'black')
    g.set_title("Lorenz curve for year {0}".format(a))
    plt.xlabel("x")
    plt.show(g)
    
lorenzCurve(2015)

# %% [markdown]
# Gini index
# ==========
#
# The [Gini index](https://en.wikipedia.org/wiki/Gini_coefficient) is twice the surface of the area comprised between curves $y=x$
# and $y=L(x)$.
#
# Choose a formula that allows you to compute it efficiently.
#
# $$G={\frac {2\sum _{i=1}^{n}iy_{i}}{n\sum _{i=1}^{n}y_{i}}}-{\frac {n+1}{n}}.$$
#
# 1. Design a query that computes the Gini index of the `babynames` distribution
# for every `year` and `sex`.
#
# 1. Plot Gini index over time

# %%
window = Window.partitionBy("year","sex").orderBy('n')
window1 = Window.partitionBy("year","sex")

gi = col('row')*col('name_proportion')
m = fn.max('row').over(window1)
den = m*fn.sum('name_proportion').over(window1)

gin_df_sp = percent_df_sp.withColumn("row",fn.row_number().over(window))\
                         .withColumn("gini",(2*fn.sum(gi).over(window1)/den)- (m+1)/m)

gin_df_sp = gin_df_sp.drop("name","n","total/year","name_proportion","row").distinct()

gin_df_sp.show()
# Out:
# +---+----+------------------+
# |sex|year|              gini|
# +---+----+------------------+
# |  F|1984|0.9006600985987916|
# |  M|1903|0.8326776921232477|
# |  F|1968|0.9133444052629038|
# |  F|1983|0.9011303160314517|
# |  F|1909|0.8694903725836292|
# |  F|1915|0.9122488979411929|
# |  M|1910|0.8510262050708011|
# |  F|1928|0.9154344188287531|
# |  F|1941|0.9192324758499943|
# |  F|1919|0.9160240819522021|
# |  F|2008|0.8570674373318883|
# |  M|1929|0.9221272684861428|
# |  F|1964| 0.921043745716531|
# |  M|1973|0.9297498818522052|
# |  M|1925|0.9231022896088341|
# |  F|1988| 0.896336559000688|
# |  M|2006|0.9017669259991061|
# |  M|1914|0.9029869981066583|
# |  F|1938|0.9150006614423067|
# |  M|1948|  0.94106319440153|
# +---+----+------------------+
# only showing top 20 rows

# %%
plt.figure(figsize = (14,10))
g = sns.lineplot(x = "year",
                 y = "gini",
                 hue = "sex",
                 data = gin_df_sp.toPandas())

g.set_title("Gini index of the babynames distribution for every year and sex")
plt.show(g)

# %% [markdown]
# Close the door, leave work area clean
# =====================================

# %%
spark.stop()
